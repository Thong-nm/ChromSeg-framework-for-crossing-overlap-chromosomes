# %%
# # mount google drive at colab runtime
# from google.colab import drive
# drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import torch
from torch import nn, optim
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import PIL.Image as Image
import os
import matplotlib.pyplot as plt
import cv2
import numpy as np
import copy
import sys
from skimage import io
from skimage.transform import resize
import shutil

# region-guided UNet++
class DoubleConv(nn.Module):
    # The convolutional layer: conv3-relu-conv3-relu
    def __init__(self, in_ch, mid_ch, out_ch):
        super(DoubleConv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, mid_ch, 3, padding=1),
            nn.BatchNorm2d(mid_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )

    def forward(self, input):
        return self.conv(input)


class UNet_plus2(nn.Module):
    
    def __init__(self, in_ch=3, out_ch=1):
        super(UNet_plus2, self).__init__()
        self.n_channels = in_ch
        self.n_classes = out_ch
        n1 = 64
        filters = [n1, n1 * 2, n1 * 4, n1 * 8]

        # Encoder: U-Net
        self.conv0_0 = DoubleConv(self.n_channels, filters[0], filters[0])
        self.pool = nn.MaxPool2d(kernel_size=3, stride=2, padding=0, ceil_mode=True)
        self.conv1_0= DoubleConv(filters[0], filters[1], filters[1])
        self.conv2_0= DoubleConv(filters[1], filters[2], filters[2])
        self.conv3_0= DoubleConv(filters[2], filters[3], filters[3])

        # Upsample layer(Deconv)
        self.up1_0 = nn.ConvTranspose2d(filters[1], filters[0], 2, stride=2)
        self.up2_0 = nn.ConvTranspose2d(filters[2], filters[1], 2, stride=2)
        self.up3_0 = nn.ConvTranspose2d(filters[3], filters[2], 2, stride=2)
        self.up1_1 = nn.ConvTranspose2d(filters[1], filters[0], 2, stride=2)
        self.up2_1 = nn.ConvTranspose2d(filters[2], filters[1], 2, stride=2)
        self.up1_2 = nn.ConvTranspose2d(filters[1], filters[0], 2, stride=2)

        # Mid Layer
        self.conv0_1 = DoubleConv(filters[0]*2, filters[0], filters[0]) 
        self.conv1_1 = DoubleConv(filters[1]*2, filters[1], filters[1])
        self.conv2_1 = DoubleConv(filters[2]*2, filters[2], filters[2])

        self.conv0_2 = DoubleConv(filters[0]*2, filters[0], filters[0])
        self.conv1_2 = DoubleConv(filters[1]*2, filters[1], filters[1])

        self.conv0_3 = DoubleConv(filters[0]*2, filters[0], filters[0])
        
        self.contour = nn.Sequential(
            nn.Conv2d(filters[0] * 2, filters[0], kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(filters[0], filters[0], kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(filters[0], out_ch, 1)
        )
        self.final = nn.Sequential(
            nn.Conv2d(filters[0], filters[0], kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(filters[0], out_ch, 1)
        )
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x0_0 = self.conv0_0(x)
        p = self.pool(x0_0)
        x1_0 = self.conv1_0(p)
        x2_0 = self.conv2_0(self.pool(x1_0))
        x3_0 = self.conv3_0(self.pool(x2_0))

        x0_1 = self.conv0_1(torch.cat([x0_0, self.up1_0(x1_0)], 1)) + x0_0
        x1_1 = self.conv1_1(torch.cat([x1_0, self.up2_0(x2_0)], 1))
        x2_1 = self.conv2_1(torch.cat([x2_0, self.up3_0(x3_0)], 1))
        
        x0_2 = self.conv0_2(torch.cat([x0_1, self.up1_1(x1_1)], 1)) + x0_1
        x1_2 = self.conv1_2(torch.cat([x1_0, self.up2_1(x2_1)], 1))
        
        x0_3 = self.conv0_3(torch.cat([x0_0, self.up1_2(x1_2)], 1))
        
        contour = self.contour(torch.cat([x0_1, x0_2], dim=1))
        output = self.final(x0_3)

        return self.sigmoid(output), self.sigmoid(contour)


# loss function
class FocalLoss(nn.Module):
    def __init__(self, gamma=2, alpha=0.5, reduction='mean'):
        super().__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.reduction = reduction

    def forward(self, _input, target):
        pt = torch.sigmoid(_input)
        pt = pt.clamp(min=0.00001,max=0.99999)
        loss = - self.alpha * (1 - pt) ** self.gamma * target * torch.log(pt) - \
            (1 - self.alpha) * pt ** self.gamma * (1 - target) * torch.log(1 - pt)

        if self.reduction == 'mean':
            loss = torch.mean(loss)
        elif self.reduction == 'sum':
            loss = torch.sum(loss)
            
        return loss


# The code to preprocessing and load dataset
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def make_dataset(root):
    imgs=[]
    for filename in os.listdir(root):
        form = filename.split('_')[0]
        if form == 'image':
            tag = filename.split('_')      
            img = os.path.join(root, filename)
            mask1 = os.path.join(root,'binary_label_' + tag[1])
            mask2 = os.path.join(root,'binary_label2_' + tag[1])
            imgs.append((img,mask1,mask2))
    return imgs

class Dataset(Dataset):
    def __init__(self, root, transform=None, target_transform=None):
    # def __init__(self, imgs, transform=None, target_transform=None):
        imgs = make_dataset(root)
        self.imgs = imgs
        self.transform = transform
        self.target_transform = target_transform

    def __getitem__(self, index):
        img, overlapped, non_overlapped = self.imgs[index]

        img_x = Image.open(img).convert('RGB')
        img_y1 = Image.open(overlapped).convert('RGB')
        img_y2 = Image.open(non_overlapped).convert('RGB')
        if self.transform is not None:
            img_x = self.transform(img_x)
        if self.target_transform is not None:
            img_y1 = img_y1.convert('L')
            img_y2 = img_y2.convert('L')
            img_y1 = self.target_transform(img_y1)
            img_y2 = self.target_transform(img_y2)
        return img_x, img_y1, img_y2

    def __len__(self):
        return len(self.imgs)

x_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

y_transforms = transforms.Compose([
    transforms.ToTensor()
])

def train_model(model, criterion, optimizer, dataloader_train, dataloader_val, num_epochs=20, patience=30): # use early stop
    min_val_loss = float('inf')
    best_epoch = 0
    best_model = None
    for epoch in range(num_epochs):
        dt_size = len(dataloader_train.dataset)
        # ----------------------TRAIN-----------------------
        model.train()
        epoch_loss = 0
        step = 0
        for x, y, c in dataloader_train:
            step += 1
            inputs = x.to(device)
            labels = y.to(device)
            labels2 = c.to(device)
            # zero the parameter gradients
            optimizer.zero_grad()
            # forward
            outputs = model(inputs)
            loss = 0.5 * criterion(outputs[0], labels) + 0.5 * criterion(outputs[1], labels2)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
            print("%d/%d,train_loss:%0.3f" % (step, (dt_size - 1) // dataloader_train.batch_size + 1, loss.item()))
        print("epoch %d training loss:%0.3f" % (epoch, epoch_loss/step))
        # ----------------------VALIDATION-----------------------
        with torch.no_grad():
            model.eval()
            epoch_loss = 0
            step = 0
            for x, y, c in dataloader_val:
                step += 1
                inputs = x.to(device)
                labels = y.to(device)
                labels2 = c.to(device)
                outputs = model(inputs)
                loss = 0.7 * criterion(outputs[0], labels) + 0.3 * criterion(outputs[1], labels2)
                epoch_loss += loss.item()
            val_loss = epoch_loss/step
            print("epoch %d validation loss:%0.5f" % (epoch, val_loss))
        if val_loss < min_val_loss:
            best_epoch = epoch
            min_val_loss = val_loss
            #torch.save(model.state_dict(), './models/weights-epoch%d-val_loss%s.pth' % (epoch, val_loss))
            best_model = copy.deepcopy(model)
        if epoch - best_epoch > patience:
            break
    print('Best validation loss%0.5f at epoch%s'% (min_val_loss, best_epoch))
    return best_model

def meanIOU_per_image(y_pred, y_true):
    '''
    Calculate the IOU, averaged across images
    '''
    y_pred = y_pred.astype('bool')
    y_true = y_true.astype('bool')
    intersection = np.logical_and(y_true, y_pred)
    union = np.logical_or(y_true, y_pred)
    
    return np.sum(intersection) / np.sum(union)

# %%
# Training
if __name__ == '__main__':
    
    args = {
        "seed": 1,
        "model_type": 'UNet_plus2',
        "dataset": '/gdrive/MyDrive/ChromSeg/ChromSeg/region-guided UNet++/dataset 6'
    }
    

    IMAGE_SIZE = 256
    batch_size = 8

    torch.manual_seed(args["seed"])    # reproducible
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(device)

    model = UNet_plus2(3, 1)
    model = model.to(device)

    gamma=1
    alpha=0.75
    criterion = FocalLoss(gamma, alpha, reduction='mean')
    optimizer = optim.Adam(model.parameters())

    dataset_train = Dataset("%s/train"% args["dataset"], transform=x_transforms, target_transform=y_transforms)
    dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True, num_workers=0)
    dataset_val = Dataset("%s/val"% args["dataset"], transform=x_transforms, target_transform=y_transforms)
    dataloader_val = DataLoader(dataset_val, batch_size=batch_size, shuffle=True, num_workers=0)

    model = train_model(model, criterion, optimizer, dataloader_train, dataloader_val, num_epochs=100, patience=7)
    
    model = model.cpu()
    dataloader_val = DataLoader(dataset_val, batch_size=1, shuffle=True, num_workers=0)

    iou = 0
    iou2 = 0
    n = 0
    model.eval()
    with torch.no_grad():
        for x, target, c in dataloader_val:
            n = n + 1
            y = model(x)
            y_pred_0 = torch.squeeze(y[0]).numpy()
            y_pred = np.zeros((256,256))
            y_pred[y_pred_0 > 0.5] = 1.0
            y_2_0 = torch.squeeze(y[1]).numpy()
            y_2 = np.zeros((256,256))
            y_2[y_2_0 > 0.5] = 1.0
            y_true = torch.squeeze(target).numpy()
            y_true2 = torch.squeeze(c).numpy()
            output1 = np.reshape(y_pred * 255,(256,256))
            output2 = np.reshape(y_2 * 255,(256,256))

            x_image = torch.squeeze(x).numpy()
            image = np.dstack((x_image[0,...]*255, x_image[1,...]*255, x_image[2,...]*255))

            cv2.imwrite('output1/' + str(n) + ".png", output1)
            cv2.imwrite('output2/' + str(n) + ".png", output2)
            cv2.imwrite('img/' + str(n) + ".png", image)
            try:
                iou += meanIOU_per_image(y_pred, y_true)
                iou2 += meanIOU_per_image(y_2, y_true2)
            except Exception as e:
                print(e)
                print('y_pred: %s'% y_pred)
                print('y_true: %s'% y_true)
                torch.save(model.state_dict(), '/gdrive/MyDrive/ChromSeg/ChromSeg/region-guided UNet++/dataset 6 result/model 1/%s_seed%s_error.pth' % (args["model_type"], args["seed"]))
                sys.exit(0)
    print("iou: ", iou)
    print("iou2: ", iou2)
    print("n: ", n)
    IoU = float(iou/n)
    IoU2 = float(iou2/n)
    
    print('Final_IoU: %s'% IoU)
    print('Final_IoU2: %s'% IoU2)
    torch.save(model.state_dict(), '/gdrive/MyDrive/ChromSeg/ChromSeg/region-guided UNet++/dataset 6 result/model 1/%s_dataset_seed%s_IoU-%0.4f_IoU-%0.4f_gamma-%d_alpha-%0.2f.pth' % (args["model_type"], args["seed"], IoU, IoU2, gamma, alpha))
# Out:
# cpu
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
model = None
model = UNet_plus2(3, 1)
model.load_state_dict(torch.load("/gdrive/MyDrive/ChromSeg/result/model/UNet_plus2_dataset_seed1_IoU-0.6803_IoU-0.9394_gamma-1_alpha-0.75.pth"))
# Out:
# <All keys matched successfully>

# %%
IMG_SIZE = 256
INPUT_PATH = "/gdrive/MyDrive/ChromSeg/result/input"
OUTPUT_PATH = '/gdrive/MyDrive/ChromSeg/result/output region-guided UNet++'

outputFolderNames = os.listdir(OUTPUT_PATH)
for folder in outputFolderNames:
    shutil.rmtree(os.path.join(OUTPUT_PATH, folder))

# get all images' name
imgNames = os.listdir(INPUT_PATH)

fig, ax = plt.subplots(len(imgNames), 3, sharex=True, sharey=True, figsize=(4.5*3, 4.5 * len(imgNames)))

for i in range(len(imgNames)):
    # get the image's name
    imageName = imgNames[i]

    # load image and resize
    ori_image = Image.open(os.path.join(INPUT_PATH, imageName)).convert('RGB')    
    ori_image = ori_image.resize((256, 256))
    image = x_transforms(ori_image)
    image = image.reshape((1,3,256,256))

    # get overlapping and non-overlapping images
    results = model(torch.Tensor(image))
    ori_image = np.array(ori_image)
    overlapped = results[0][0][0].detach().numpy() * 255
    non_overlapped = results[1][0][0].detach().numpy() * 255

    ax[i][0].imshow(ori_image, cmap='gray')
    ax[i][1].imshow(overlapped, cmap='gray')
    ax[i][2].imshow(non_overlapped, cmap='gray')
    fig.tight_layout()

    # saving the result
    output_path = os.path.join(OUTPUT_PATH, str(i))
    if not os.path.exists(output_path):
        os.mkdir(output_path)

    os.path.join(output_path, "non_overlapped.png")

    cv2.imwrite(os.path.join(output_path, "original.png"), ori_image)
    cv2.imwrite(os.path.join(output_path, "overlapped.png"), overlapped)
    cv2.imwrite(os.path.join(output_path, "non_overlapped.png"), non_overlapped)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
os.listdir(INPUT_PATH)
# Out:
# ['1.png', '2.png', '0.png']

# %%
a = '''1/40,train_loss:0.153
2/40,train_loss:0.144
3/40,train_loss:0.136
4/40,train_loss:0.132
5/40,train_loss:0.131
6/40,train_loss:0.128
7/40,train_loss:0.125
8/40,train_loss:0.125
9/40,train_loss:0.123
10/40,train_loss:0.121
11/40,train_loss:0.120
12/40,train_loss:0.119
13/40,train_loss:0.118
14/40,train_loss:0.117
15/40,train_loss:0.117
16/40,train_loss:0.116
17/40,train_loss:0.115
18/40,train_loss:0.114
19/40,train_loss:0.114
20/40,train_loss:0.113
21/40,train_loss:0.113
22/40,train_loss:0.112
23/40,train_loss:0.111
24/40,train_loss:0.111
25/40,train_loss:0.110
26/40,train_loss:0.110
27/40,train_loss:0.109
28/40,train_loss:0.109
29/40,train_loss:0.109
30/40,train_loss:0.108
31/40,train_loss:0.108
32/40,train_loss:0.107
33/40,train_loss:0.107
34/40,train_loss:0.107
35/40,train_loss:0.106
36/40,train_loss:0.106
37/40,train_loss:0.105
38/40,train_loss:0.105
39/40,train_loss:0.105
40/40,train_loss:0.104
epoch 0 training loss:0.116
epoch 0 validation loss:0.11291
1/40,train_loss:0.104
2/40,train_loss:0.104
3/40,train_loss:0.103
4/40,train_loss:0.103
5/40,train_loss:0.103
6/40,train_loss:0.102
7/40,train_loss:0.102
8/40,train_loss:0.102
9/40,train_loss:0.101
10/40,train_loss:0.101
11/40,train_loss:0.101
12/40,train_loss:0.101
13/40,train_loss:0.101
14/40,train_loss:0.101
15/40,train_loss:0.101
16/40,train_loss:0.100
17/40,train_loss:0.100
18/40,train_loss:0.100
19/40,train_loss:0.099
20/40,train_loss:0.099
21/40,train_loss:0.099
22/40,train_loss:0.099
23/40,train_loss:0.098
24/40,train_loss:0.098
25/40,train_loss:0.098
26/40,train_loss:0.098
27/40,train_loss:0.097
28/40,train_loss:0.097
29/40,train_loss:0.097
30/40,train_loss:0.097
31/40,train_loss:0.097
32/40,train_loss:0.097
33/40,train_loss:0.096
34/40,train_loss:0.096
35/40,train_loss:0.096
36/40,train_loss:0.096
37/40,train_loss:0.096
38/40,train_loss:0.096
39/40,train_loss:0.095
40/40,train_loss:0.095
epoch 1 training loss:0.099
epoch 1 validation loss:0.09612
1/40,train_loss:0.095
2/40,train_loss:0.095
3/40,train_loss:0.095
4/40,train_loss:0.095
5/40,train_loss:0.095
6/40,train_loss:0.095
7/40,train_loss:0.094
8/40,train_loss:0.094
9/40,train_loss:0.094
10/40,train_loss:0.094
11/40,train_loss:0.094
12/40,train_loss:0.094
13/40,train_loss:0.094
14/40,train_loss:0.094
15/40,train_loss:0.093
16/40,train_loss:0.093
17/40,train_loss:0.093
18/40,train_loss:0.093
19/40,train_loss:0.093
20/40,train_loss:0.093
21/40,train_loss:0.093
22/40,train_loss:0.093
23/40,train_loss:0.093
24/40,train_loss:0.093
25/40,train_loss:0.093
26/40,train_loss:0.093
27/40,train_loss:0.093
28/40,train_loss:0.092
29/40,train_loss:0.092
30/40,train_loss:0.092
31/40,train_loss:0.092
32/40,train_loss:0.092
33/40,train_loss:0.092
34/40,train_loss:0.092
35/40,train_loss:0.092
36/40,train_loss:0.092
37/40,train_loss:0.092
38/40,train_loss:0.092
39/40,train_loss:0.092
40/40,train_loss:0.091
epoch 2 training loss:0.093
epoch 2 validation loss:0.09170
1/40,train_loss:0.091
2/40,train_loss:0.091
3/40,train_loss:0.092
4/40,train_loss:0.091
5/40,train_loss:0.091
6/40,train_loss:0.091
7/40,train_loss:0.091
8/40,train_loss:0.091
9/40,train_loss:0.091
10/40,train_loss:0.091
11/40,train_loss:0.091
12/40,train_loss:0.091
13/40,train_loss:0.091
14/40,train_loss:0.091
15/40,train_loss:0.091
16/40,train_loss:0.091
17/40,train_loss:0.091
18/40,train_loss:0.091
19/40,train_loss:0.091
20/40,train_loss:0.090
21/40,train_loss:0.090
22/40,train_loss:0.091
23/40,train_loss:0.090
24/40,train_loss:0.090
25/40,train_loss:0.090
26/40,train_loss:0.090
27/40,train_loss:0.090
28/40,train_loss:0.090
29/40,train_loss:0.090
30/40,train_loss:0.090
31/40,train_loss:0.090
32/40,train_loss:0.090
33/40,train_loss:0.090
34/40,train_loss:0.090
35/40,train_loss:0.090
36/40,train_loss:0.090
37/40,train_loss:0.090
38/40,train_loss:0.090
39/40,train_loss:0.090
40/40,train_loss:0.090
epoch 3 training loss:0.091
epoch 3 validation loss:0.09310
1/40,train_loss:0.090
2/40,train_loss:0.090
3/40,train_loss:0.090
4/40,train_loss:0.090
5/40,train_loss:0.090
6/40,train_loss:0.090
7/40,train_loss:0.090
8/40,train_loss:0.089
9/40,train_loss:0.090
10/40,train_loss:0.090
11/40,train_loss:0.089
12/40,train_loss:0.089
13/40,train_loss:0.089
14/40,train_loss:0.089
15/40,train_loss:0.089
16/40,train_loss:0.089
17/40,train_loss:0.089
18/40,train_loss:0.089
19/40,train_loss:0.089
20/40,train_loss:0.089
21/40,train_loss:0.089
22/40,train_loss:0.089
23/40,train_loss:0.089
24/40,train_loss:0.089
25/40,train_loss:0.089
26/40,train_loss:0.089
27/40,train_loss:0.089
28/40,train_loss:0.089
29/40,train_loss:0.089
30/40,train_loss:0.089
31/40,train_loss:0.089
32/40,train_loss:0.089
33/40,train_loss:0.089
34/40,train_loss:0.089
35/40,train_loss:0.089
36/40,train_loss:0.089
37/40,train_loss:0.089
38/40,train_loss:0.089
39/40,train_loss:0.089
40/40,train_loss:0.089
epoch 4 training loss:0.089
epoch 4 validation loss:0.10313
1/40,train_loss:0.089
2/40,train_loss:0.089
3/40,train_loss:0.089
4/40,train_loss:0.089
5/40,train_loss:0.089
6/40,train_loss:0.089
7/40,train_loss:0.089
8/40,train_loss:0.089
9/40,train_loss:0.089
10/40,train_loss:0.089
11/40,train_loss:0.089
12/40,train_loss:0.089
13/40,train_loss:0.089
14/40,train_loss:0.089
15/40,train_loss:0.088
16/40,train_loss:0.089
17/40,train_loss:0.089
18/40,train_loss:0.089
19/40,train_loss:0.088
20/40,train_loss:0.088
21/40,train_loss:0.089
22/40,train_loss:0.088
23/40,train_loss:0.088
24/40,train_loss:0.088
25/40,train_loss:0.088
26/40,train_loss:0.089
27/40,train_loss:0.088
28/40,train_loss:0.088
29/40,train_loss:0.088
30/40,train_loss:0.088
31/40,train_loss:0.088
32/40,train_loss:0.088
33/40,train_loss:0.088
34/40,train_loss:0.088
35/40,train_loss:0.088
36/40,train_loss:0.088
37/40,train_loss:0.088
38/40,train_loss:0.088
39/40,train_loss:0.088
40/40,train_loss:0.088
epoch 5 training loss:0.089
epoch 5 validation loss:0.08838
1/40,train_loss:0.088
2/40,train_loss:0.088
3/40,train_loss:0.088
4/40,train_loss:0.088
5/40,train_loss:0.088
6/40,train_loss:0.088
7/40,train_loss:0.088
8/40,train_loss:0.088
9/40,train_loss:0.088
10/40,train_loss:0.088
11/40,train_loss:0.088
12/40,train_loss:0.088
13/40,train_loss:0.088
14/40,train_loss:0.088
15/40,train_loss:0.088
16/40,train_loss:0.088
17/40,train_loss:0.088
18/40,train_loss:0.088
19/40,train_loss:0.088
20/40,train_loss:0.088
21/40,train_loss:0.088
22/40,train_loss:0.088
23/40,train_loss:0.088
24/40,train_loss:0.088
25/40,train_loss:0.088
26/40,train_loss:0.088
27/40,train_loss:0.088
28/40,train_loss:0.088
29/40,train_loss:0.088
30/40,train_loss:0.088
31/40,train_loss:0.088
32/40,train_loss:0.088
33/40,train_loss:0.088
34/40,train_loss:0.088
35/40,train_loss:0.088
36/40,train_loss:0.088
37/40,train_loss:0.088
38/40,train_loss:0.088
39/40,train_loss:0.088
40/40,train_loss:0.088
epoch 6 training loss:0.088
epoch 6 validation loss:0.08840
1/40,train_loss:0.088
2/40,train_loss:0.088
3/40,train_loss:0.088
4/40,train_loss:0.088
5/40,train_loss:0.088
6/40,train_loss:0.088
7/40,train_loss:0.088
8/40,train_loss:0.088
9/40,train_loss:0.088
10/40,train_loss:0.088
11/40,train_loss:0.088
12/40,train_loss:0.088
13/40,train_loss:0.088
14/40,train_loss:0.088
15/40,train_loss:0.088
16/40,train_loss:0.087
17/40,train_loss:0.088
18/40,train_loss:0.088
19/40,train_loss:0.088
20/40,train_loss:0.088
21/40,train_loss:0.087
22/40,train_loss:0.088
23/40,train_loss:0.087
24/40,train_loss:0.087
25/40,train_loss:0.088
26/40,train_loss:0.088
27/40,train_loss:0.088
28/40,train_loss:0.088
29/40,train_loss:0.088
30/40,train_loss:0.088
31/40,train_loss:0.088
32/40,train_loss:0.088
33/40,train_loss:0.088
34/40,train_loss:0.087
35/40,train_loss:0.088
36/40,train_loss:0.088
37/40,train_loss:0.088
38/40,train_loss:0.088
39/40,train_loss:0.088
40/40,train_loss:0.087
epoch 7 training loss:0.088
epoch 7 validation loss:0.08762
1/40,train_loss:0.088
2/40,train_loss:0.087
3/40,train_loss:0.087
4/40,train_loss:0.087
5/40,train_loss:0.087
6/40,train_loss:0.087
7/40,train_loss:0.087
8/40,train_loss:0.087
9/40,train_loss:0.087
10/40,train_loss:0.087
11/40,train_loss:0.087
12/40,train_loss:0.087
13/40,train_loss:0.087
14/40,train_loss:0.087
15/40,train_loss:0.087
16/40,train_loss:0.087
17/40,train_loss:0.087
18/40,train_loss:0.087
19/40,train_loss:0.087
20/40,train_loss:0.087
21/40,train_loss:0.087
22/40,train_loss:0.087
23/40,train_loss:0.087
24/40,train_loss:0.087
25/40,train_loss:0.087
26/40,train_loss:0.087
27/40,train_loss:0.087
28/40,train_loss:0.087
29/40,train_loss:0.087
30/40,train_loss:0.087
31/40,train_loss:0.087
32/40,train_loss:0.087
33/40,train_loss:0.087
34/40,train_loss:0.087
35/40,train_loss:0.087
36/40,train_loss:0.087
37/40,train_loss:0.087
38/40,train_loss:0.087
39/40,train_loss:0.087
40/40,train_loss:0.087
epoch 8 training loss:0.087
epoch 8 validation loss:0.09220
1/40,train_loss:0.087
2/40,train_loss:0.087
3/40,train_loss:0.087
4/40,train_loss:0.087
5/40,train_loss:0.087
6/40,train_loss:0.087
7/40,train_loss:0.087
8/40,train_loss:0.087
9/40,train_loss:0.087
10/40,train_loss:0.087
11/40,train_loss:0.087
12/40,train_loss:0.087
13/40,train_loss:0.087
14/40,train_loss:0.087
15/40,train_loss:0.087
16/40,train_loss:0.087
17/40,train_loss:0.087
18/40,train_loss:0.087
19/40,train_loss:0.087
20/40,train_loss:0.087
21/40,train_loss:0.087
22/40,train_loss:0.087
23/40,train_loss:0.087
24/40,train_loss:0.087
25/40,train_loss:0.087
26/40,train_loss:0.087
27/40,train_loss:0.087
28/40,train_loss:0.087
29/40,train_loss:0.087
30/40,train_loss:0.087
31/40,train_loss:0.087
32/40,train_loss:0.087
33/40,train_loss:0.087
34/40,train_loss:0.087
35/40,train_loss:0.087
36/40,train_loss:0.087
37/40,train_loss:0.087
38/40,train_loss:0.087
39/40,train_loss:0.087
40/40,train_loss:0.087
epoch 9 training loss:0.087
epoch 9 validation loss:0.08748
1/40,train_loss:0.087
2/40,train_loss:0.087
3/40,train_loss:0.087
4/40,train_loss:0.087
5/40,train_loss:0.087
6/40,train_loss:0.087
7/40,train_loss:0.087
8/40,train_loss:0.087
9/40,train_loss:0.087
10/40,train_loss:0.087
11/40,train_loss:0.087
12/40,train_loss:0.087
13/40,train_loss:0.087
14/40,train_loss:0.087
15/40,train_loss:0.087
16/40,train_loss:0.087
17/40,train_loss:0.087
18/40,train_loss:0.087
19/40,train_loss:0.087
20/40,train_loss:0.087
21/40,train_loss:0.087
22/40,train_loss:0.087
23/40,train_loss:0.087
24/40,train_loss:0.087
25/40,train_loss:0.087
26/40,train_loss:0.087
27/40,train_loss:0.087
28/40,train_loss:0.087
29/40,train_loss:0.087
30/40,train_loss:0.087
31/40,train_loss:0.087
32/40,train_loss:0.087
33/40,train_loss:0.087
34/40,train_loss:0.087
35/40,train_loss:0.087
36/40,train_loss:0.087
37/40,train_loss:0.087
38/40,train_loss:0.087
39/40,train_loss:0.087
40/40,train_loss:0.087
epoch 10 training loss:0.087
epoch 10 validation loss:0.08717
1/40,train_loss:0.087
2/40,train_loss:0.087
3/40,train_loss:0.087
4/40,train_loss:0.087
5/40,train_loss:0.087
6/40,train_loss:0.087
7/40,train_loss:0.087
8/40,train_loss:0.087
9/40,train_loss:0.087
10/40,train_loss:0.087
11/40,train_loss:0.087
12/40,train_loss:0.087
13/40,train_loss:0.087
14/40,train_loss:0.087
15/40,train_loss:0.087
16/40,train_loss:0.087
17/40,train_loss:0.087
18/40,train_loss:0.087
19/40,train_loss:0.087
20/40,train_loss:0.087
21/40,train_loss:0.087
22/40,train_loss:0.087
23/40,train_loss:0.087
24/40,train_loss:0.087
25/40,train_loss:0.087
26/40,train_loss:0.087
27/40,train_loss:0.087
28/40,train_loss:0.087
29/40,train_loss:0.087
30/40,train_loss:0.087
31/40,train_loss:0.087
32/40,train_loss:0.087
33/40,train_loss:0.087
34/40,train_loss:0.087
35/40,train_loss:0.087
36/40,train_loss:0.087
37/40,train_loss:0.087
38/40,train_loss:0.087
39/40,train_loss:0.087
40/40,train_loss:0.086
epoch 11 training loss:0.087
epoch 11 validation loss:0.08721
1/40,train_loss:0.087
2/40,train_loss:0.087
3/40,train_loss:0.087
4/40,train_loss:0.087
5/40,train_loss:0.087
6/40,train_loss:0.087
7/40,train_loss:0.087
8/40,train_loss:0.087
9/40,train_loss:0.087
10/40,train_loss:0.087
11/40,train_loss:0.087
12/40,train_loss:0.087
13/40,train_loss:0.087
14/40,train_loss:0.087
15/40,train_loss:0.087
16/40,train_loss:0.087
17/40,train_loss:0.087
18/40,train_loss:0.087
19/40,train_loss:0.087
20/40,train_loss:0.087
21/40,train_loss:0.087
22/40,train_loss:0.087
23/40,train_loss:0.087
24/40,train_loss:0.087
25/40,train_loss:0.087
26/40,train_loss:0.087
27/40,train_loss:0.087
28/40,train_loss:0.087
29/40,train_loss:0.087
30/40,train_loss:0.087
31/40,train_loss:0.087
32/40,train_loss:0.087
33/40,train_loss:0.087
34/40,train_loss:0.087
35/40,train_loss:0.087
36/40,train_loss:0.087
37/40,train_loss:0.087
38/40,train_loss:0.087
39/40,train_loss:0.087
40/40,train_loss:0.087
epoch 12 training loss:0.087
epoch 12 validation loss:0.08704
1/40,train_loss:0.087
2/40,train_loss:0.087
3/40,train_loss:0.087
4/40,train_loss:0.087
5/40,train_loss:0.087
6/40,train_loss:0.087
7/40,train_loss:0.087
8/40,train_loss:0.087
9/40,train_loss:0.087
10/40,train_loss:0.087
11/40,train_loss:0.087
12/40,train_loss:0.087
13/40,train_loss:0.087
14/40,train_loss:0.087
15/40,train_loss:0.087
16/40,train_loss:0.087
17/40,train_loss:0.087
18/40,train_loss:0.087
19/40,train_loss:0.087
20/40,train_loss:0.087
21/40,train_loss:0.087
22/40,train_loss:0.087
23/40,train_loss:0.087
24/40,train_loss:0.087
25/40,train_loss:0.087
26/40,train_loss:0.087
27/40,train_loss:0.087
28/40,train_loss:0.087
29/40,train_loss:0.087
30/40,train_loss:0.087
31/40,train_loss:0.087
32/40,train_loss:0.087
33/40,train_loss:0.087
34/40,train_loss:0.087
35/40,train_loss:0.087
36/40,train_loss:0.087
37/40,train_loss:0.087
38/40,train_loss:0.087
39/40,train_loss:0.087
40/40,train_loss:0.087
epoch 13 training loss:0.087
epoch 13 validation loss:0.08698
1/40,train_loss:0.087
2/40,train_loss:0.087
3/40,train_loss:0.087
4/40,train_loss:0.087
5/40,train_loss:0.087
6/40,train_loss:0.087
7/40,train_loss:0.087
8/40,train_loss:0.087
9/40,train_loss:0.087
10/40,train_loss:0.087
11/40,train_loss:0.087
12/40,train_loss:0.087
13/40,train_loss:0.087
14/40,train_loss:0.087
15/40,train_loss:0.087
16/40,train_loss:0.087
17/40,train_loss:0.087
18/40,train_loss:0.087
19/40,train_loss:0.087
20/40,train_loss:0.087
21/40,train_loss:0.087
22/40,train_loss:0.087
23/40,train_loss:0.087
24/40,train_loss:0.087
25/40,train_loss:0.087
26/40,train_loss:0.087
27/40,train_loss:0.087
28/40,train_loss:0.087
29/40,train_loss:0.087
30/40,train_loss:0.087
31/40,train_loss:0.087
32/40,train_loss:0.087
33/40,train_loss:0.087
34/40,train_loss:0.087
35/40,train_loss:0.087
36/40,train_loss:0.087
37/40,train_loss:0.087
38/40,train_loss:0.087
39/40,train_loss:0.087
40/40,train_loss:0.087
epoch 14 training loss:0.087
epoch 14 validation loss:0.08713
1/40,train_loss:0.087
2/40,train_loss:0.087
3/40,train_loss:0.087
4/40,train_loss:0.087
5/40,train_loss:0.087
6/40,train_loss:0.087
7/40,train_loss:0.087
8/40,train_loss:0.087
9/40,train_loss:0.087
10/40,train_loss:0.087
11/40,train_loss:0.087
12/40,train_loss:0.086
13/40,train_loss:0.087
14/40,train_loss:0.087
15/40,train_loss:0.086
16/40,train_loss:0.087
17/40,train_loss:0.087
18/40,train_loss:0.087
19/40,train_loss:0.087
20/40,train_loss:0.087
21/40,train_loss:0.087
22/40,train_loss:0.087
23/40,train_loss:0.087
24/40,train_loss:0.087
25/40,train_loss:0.087
26/40,train_loss:0.087
27/40,train_loss:0.087
28/40,train_loss:0.087
29/40,train_loss:0.087
30/40,train_loss:0.087
31/40,train_loss:0.087
32/40,train_loss:0.087
33/40,train_loss:0.087
34/40,train_loss:0.087
35/40,train_loss:0.087
36/40,train_loss:0.087
37/40,train_loss:0.087
38/40,train_loss:0.087
39/40,train_loss:0.087
40/40,train_loss:0.087
epoch 15 training loss:0.087
epoch 15 validation loss:0.08699
1/40,train_loss:0.087
2/40,train_loss:0.086
3/40,train_loss:0.087
4/40,train_loss:0.087
5/40,train_loss:0.087
6/40,train_loss:0.087
7/40,train_loss:0.087
8/40,train_loss:0.087
9/40,train_loss:0.087
10/40,train_loss:0.087
11/40,train_loss:0.087
12/40,train_loss:0.087
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.087
16/40,train_loss:0.087
17/40,train_loss:0.087
18/40,train_loss:0.087
19/40,train_loss:0.087
20/40,train_loss:0.086
21/40,train_loss:0.087
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.087
25/40,train_loss:0.086
26/40,train_loss:0.087
27/40,train_loss:0.087
28/40,train_loss:0.086
29/40,train_loss:0.087
30/40,train_loss:0.086
31/40,train_loss:0.087
32/40,train_loss:0.086
33/40,train_loss:0.087
34/40,train_loss:0.087
35/40,train_loss:0.087
36/40,train_loss:0.087
37/40,train_loss:0.087
38/40,train_loss:0.087
39/40,train_loss:0.086
40/40,train_loss:0.087
epoch 16 training loss:0.087
epoch 16 validation loss:0.08698
1/40,train_loss:0.086
2/40,train_loss:0.087
3/40,train_loss:0.087
4/40,train_loss:0.087
5/40,train_loss:0.087
6/40,train_loss:0.087
7/40,train_loss:0.086
8/40,train_loss:0.087
9/40,train_loss:0.087
10/40,train_loss:0.087
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.087
15/40,train_loss:0.087
16/40,train_loss:0.087
17/40,train_loss:0.087
18/40,train_loss:0.087
19/40,train_loss:0.086
20/40,train_loss:0.087
21/40,train_loss:0.087
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.087
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.087
28/40,train_loss:0.087
29/40,train_loss:0.087
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.087
35/40,train_loss:0.087
36/40,train_loss:0.086
37/40,train_loss:0.087
38/40,train_loss:0.087
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 17 training loss:0.087
epoch 17 validation loss:0.08699
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.087
5/40,train_loss:0.087
6/40,train_loss:0.087
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.087
10/40,train_loss:0.087
11/40,train_loss:0.087
12/40,train_loss:0.087
13/40,train_loss:0.087
14/40,train_loss:0.086
15/40,train_loss:0.087
16/40,train_loss:0.086
17/40,train_loss:0.087
18/40,train_loss:0.086
19/40,train_loss:0.087
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.087
27/40,train_loss:0.087
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.087
31/40,train_loss:0.087
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.087
38/40,train_loss:0.087
39/40,train_loss:0.086
40/40,train_loss:0.087
epoch 18 training loss:0.086
epoch 18 validation loss:0.08683
1/40,train_loss:0.087
2/40,train_loss:0.087
3/40,train_loss:0.086
4/40,train_loss:0.087
5/40,train_loss:0.087
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.087
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.087
23/40,train_loss:0.087
24/40,train_loss:0.086
25/40,train_loss:0.087
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.087
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.087
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 19 training loss:0.086
epoch 19 validation loss:0.08687
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.087
7/40,train_loss:0.086
8/40,train_loss:0.087
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.087
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.087
18/40,train_loss:0.087
19/40,train_loss:0.087
20/40,train_loss:0.087
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.087
25/40,train_loss:0.087
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.087
29/40,train_loss:0.087
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.087
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.087
epoch 20 training loss:0.086
epoch 20 validation loss:0.08736
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.087
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.087
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.087
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.087
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 21 training loss:0.086
epoch 21 validation loss:0.08679
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.087
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.087
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.087
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 22 training loss:0.086
epoch 22 validation loss:0.08686
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.087
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 23 training loss:0.086
epoch 23 validation loss:0.08680
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.087
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.087
epoch 24 training loss:0.086
epoch 24 validation loss:0.08679
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 25 training loss:0.086
epoch 25 validation loss:0.12880
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.087
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 26 training loss:0.086
epoch 26 validation loss:0.08675
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 27 training loss:0.086
epoch 27 validation loss:0.08690
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.087
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 28 training loss:0.086
epoch 28 validation loss:0.08680
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.087
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 29 training loss:0.086
epoch 29 validation loss:0.08681
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 30 training loss:0.086
epoch 30 validation loss:0.08674
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 31 training loss:0.086
epoch 31 validation loss:0.12495
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 32 training loss:0.086
epoch 32 validation loss:0.08674
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 33 training loss:0.086
epoch 33 validation loss:0.08671
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 34 training loss:0.086
epoch 34 validation loss:0.11738
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 35 training loss:0.086
epoch 35 validation loss:0.08672
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 36 training loss:0.086
epoch 36 validation loss:0.08673
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 37 training loss:0.086
epoch 37 validation loss:0.08674
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 38 training loss:0.086
epoch 38 validation loss:0.08671
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 39 training loss:0.086
epoch 39 validation loss:0.08672
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 40 training loss:0.086
epoch 40 validation loss:0.08670
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 41 training loss:0.086
epoch 41 validation loss:0.08672
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 42 training loss:0.086
epoch 42 validation loss:0.08679
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 43 training loss:0.086
epoch 43 validation loss:0.08669
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 44 training loss:0.086
epoch 44 validation loss:0.08671
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 45 training loss:0.086
epoch 45 validation loss:0.08669
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 46 training loss:0.086
epoch 46 validation loss:0.08670
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 47 training loss:0.086
epoch 47 validation loss:0.08686
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 48 training loss:0.086
epoch 48 validation loss:0.08669
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 49 training loss:0.086
epoch 49 validation loss:0.08680
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 50 training loss:0.086
epoch 50 validation loss:0.08668
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 51 training loss:0.086
epoch 51 validation loss:0.08670
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 52 training loss:0.086
epoch 52 validation loss:0.08669
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 53 training loss:0.086
epoch 53 validation loss:0.08672
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 54 training loss:0.086
epoch 54 validation loss:0.08669
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 55 training loss:0.086
epoch 55 validation loss:0.08670
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 56 training loss:0.086
epoch 56 validation loss:0.08670
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 57 training loss:0.086
epoch 57 validation loss:0.08667
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 58 training loss:0.086
epoch 58 validation loss:0.08669
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 59 training loss:0.086
epoch 59 validation loss:0.08669
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 60 training loss:0.086
epoch 60 validation loss:0.08671
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 61 training loss:0.086
epoch 61 validation loss:0.08670
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 62 training loss:0.086
epoch 62 validation loss:0.08672
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 63 training loss:0.086
epoch 63 validation loss:0.08668
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 64 training loss:0.086
epoch 64 validation loss:0.08670
1/40,train_loss:0.086
2/40,train_loss:0.086
3/40,train_loss:0.086
4/40,train_loss:0.086
5/40,train_loss:0.086
6/40,train_loss:0.086
7/40,train_loss:0.086
8/40,train_loss:0.086
9/40,train_loss:0.086
10/40,train_loss:0.086
11/40,train_loss:0.086
12/40,train_loss:0.086
13/40,train_loss:0.086
14/40,train_loss:0.086
15/40,train_loss:0.086
16/40,train_loss:0.086
17/40,train_loss:0.086
18/40,train_loss:0.086
19/40,train_loss:0.086
20/40,train_loss:0.086
21/40,train_loss:0.086
22/40,train_loss:0.086
23/40,train_loss:0.086
24/40,train_loss:0.086
25/40,train_loss:0.086
26/40,train_loss:0.086
27/40,train_loss:0.086
28/40,train_loss:0.086
29/40,train_loss:0.086
30/40,train_loss:0.086
31/40,train_loss:0.086
32/40,train_loss:0.086
33/40,train_loss:0.086
34/40,train_loss:0.086
35/40,train_loss:0.086
36/40,train_loss:0.086
37/40,train_loss:0.086
38/40,train_loss:0.086
39/40,train_loss:0.086
40/40,train_loss:0.086
epoch 65 training loss:0.086
epoch 65 validation loss:0.08671'''

# %%
b = a.split("\n")
c, d = [], []
for i in b:
    if "training loss:" in i:
        e = i.split(":")[1]
        c.append(float(e))
    elif "validation loss:" in i:
        e = i.split(":")[1]
        d.append(float(e))
print(len(d))
len(c)
x = list(range(0, 66))
# Out:
# 66

# %%
d
# Out:
# [0.11291,
#  0.09612,
#  0.0917,
#  0.0931,
#  0.10313,
#  0.08838,
#  0.0884,
#  0.08762,
#  0.0922,
#  0.08748,
#  0.08717,
#  0.08721,
#  0.08704,
#  0.08698,
#  0.08713,
#  0.08699,
#  0.08698,
#  0.08699,
#  0.08683,
#  0.08687,
#  0.08736,
#  0.08679,
#  0.08686,
#  0.0868,
#  0.08679,
#  0.1288,
#  0.08675,
#  0.0869,
#  0.0868,
#  0.08681,
#  0.08674,
#  0.12495,
#  0.08674,
#  0.08671,
#  0.11738,
#  0.08672,
#  0.08673,
#  0.08674,
#  0.08671,
#  0.08672,
#  0.0867,
#  0.08672,
#  0.08679,
#  0.08669,
#  0.08671,
#  0.08669,
#  0.0867,
#  0.08686,
#  0.08669,
#  0.0868,
#  0.08668,
#  0.0867,
#  0.08669,
#  0.08672,
#  0.08669,
#  0.0867,
#  0.0867,
#  0.08667,
#  0.08669,
#  0.08669,
#  0.08671,
#  0.0867,
#  0.08672,
#  0.08668,
#  0.0867,
#  0.08671]

# %%
plt.plot(x, c)
plt.plot(x, d)
# plt.xlim(0, 40)
# plt.ylim(0, 1)
plt.xlabel('Epoch')
plt.ylabel("Loss value")
plt.show()
